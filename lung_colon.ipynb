# %% [markdown]
# <a href="https://colab.research.google.com/github/apananya3p7-prog/My-Proj/blob/main/lung_colon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1fcc7f7f-6ddf-448d-9934-9a9f8f32d2a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1fcc7f7f-6ddf-448d-9934-9a9f8f32d2a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from tensorflow.keras.models import load_model

# Replace with your actual file name if different
model = load_model('Model.h5')

print("Model loaded successfully!")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully!

# %%
from google.colab import files

# Upload kaggle.json file manually
files.upload()
# Out:
#      <input type="file" id="files-79ef0769-0f8d-4296-a4ca-d683143b5f75" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-79ef0769-0f8d-4296-a4ca-d683143b5f75">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# Move kaggle.json to the correct directory
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json  # Set correct permissions

# Download the dataset
# !kaggle datasets download -d andrewmvd/lung-and-colon-cancer-histopathological-images

# Extract the dataset
# !unzip lung-and-colon-cancer-histopathological-images.zip -d cancer_data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: cancer_data/lung_colon_image_set/lung_image_sets/lung_scc/lungscc1.jpeg
#   inflating: cancer_data/lung_colon_image_set/lung_image_sets/lung_scc/lungscc10.jpeg
#   inflating: cancer_data/lung_colon_image_set/lung_image_sets/lung_scc/lungscc100.jpeg
#   inflating: cancer_data/lung_colon_image_set/lung_image_sets/lung_scc/lungscc1000.jpeg
#   inflating: cancer_data/lung_colon_image_set/lung_image_sets/lung_scc/lungscc1001.jpeg
#   inflating: cancer_data/lung_colon_image_set/lung_image_sets/lung_scc/lungscc1002.jpeg
#   inflating: cancer_data/lung_colon_image_set/lung_image_sets/lung_scc/lungscc1003.jpeg
#   inflating: cancer_data/lung_colon_image_set/lung_image_sets/lung_scc/lungscc1004.jpeg
#   inflating: cancer_data/lung_colon_image_set/lung_image_sets/lung_scc/lungscc1005.jpeg
#   inflating: cancer_data/lung_colon_image_set/lung_image_sets/lung_scc/lungscc1006.jpeg
# ...

# %%
class_names = [
    'Lung benign tissue',
    'Lung adenocarcinoma',
    'Lung squamous cell carcinoma',
    'Colon adenocarcinoma',
    'Colon benign tissue'
]

# %%
import os
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# %%
img_size = (224, 224)  # Must match training size

# %%
class_names = [
    'Lung benign tissue',
    'Lung adenocarcinoma',
    'Lung squamous cell carcinoma',
    'Colon adenocarcinoma',
    'Colon benign tissue'
]

# %%
import os
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
import random

# Correct image path based on your previous data
image_path = "/content/cancer_data/lung_colon_image_set/lung_image_sets/lung_scc/lungscc2345.jpeg"  # Example for Lung Squamous Cell Carcinoma image

# Check if the image exists
if os.path.exists(image_path):
    print("✅ Image found! Proceeding with prediction...")
else:
    raise FileNotFoundError("❌ Image not found! Double-check the filename or path.")

# Load and preprocess the image
img = Image.open(image_path).convert("RGB")
img = img.resize((224, 224))  # Resize to expected size (224x224 for most models)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Add batch dimension

# Assuming your model is already loaded (do not load again)
# 'loaded_model' is already available in your environment

# Make prediction
predictions = loaded_model.predict(img_array)

# Class labels as per your model (make sure these match your model's output classes)
class_labels = [
    "Colon Adenocarcinoma",
    "Colon Benign Tissue",
    "Lung Adenocarcinoma",
    "Lung Benign Tissue",
    "Lung Squamous Cell Carcinoma"
]

# Output prediction
predicted_class = class_labels[tf.argmax(predictions[0])]

# Print the predicted class
print(f"Predicted: {predicted_class}")

# Personalized treatment and doctor information for Lung Squamous Cell Carcinoma
if predicted_class == "Lung Squamous Cell Carcinoma":
    print("\n⚠️ Personalized Treatment Recommendation:")
    print("Treatment for Lung Squamous Cell Carcinoma may include chemotherapy, targeted therapy, immunotherapy, and/or surgery.")
    print("Please consult your oncologist for a personalized treatment plan.")

    # Random doctor phone number
    doctor_phone = f"Dr. {random.choice(['Smith', 'Johnson', 'Lee', 'Chen', 'Patel'])} - Phone: +1-{random.randint(100, 999)}-{random.randint(1000000, 9999999)}"
    print(f"\n📞 Contact Information:\n{doctor_phone}")

# Display the image with predicted class in the title
plt.imshow(img)
plt.axis('off')  # Hide axes for better visualization
plt.title(f"Prediction: {predicted_class}")
plt.show()
# Out:
# ✅ Image found! Proceeding with prediction...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7a1c4b872d52> in <cell line: 0>()
#      24
#      25 # Make prediction
# ---> 26 predictions = loaded_model.predict(img_array)
#      27
#      28 # Class labels as per your model (make sure these match your model's output classes)
#
# NameError: name 'loaded_model' is not defined

# %%
from PIL import Image
import tensorflow as tf

# Correct image path (pick an available image)
image_path = "/content/cancer_data/lung_colon_image_set/lung_image_sets/lung_aca/lungaca794.jpeg"

# Check if the image exists
if os.path.exists(image_path):
    print("✅ Image found! Proceeding with prediction...")
else:
    raise FileNotFoundError("❌ Image not found! Double-check the filename or path.")

# Load and preprocess the image
img = Image.open(image_path)
img = img.resize((224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# Make predictions
predictions = loaded_model.predict(img_array)
class_labels = ["Colon Adenocarcinoma", "Colon Benign Tissue", "Lung Adenocarcinoma", "Lung Benign Tissue", "Lung Squamous Cell Carcinoma"]  # Update as per your classes
score = tf.nn.softmax(predictions[0])

# Print predicted class
print(f"Predicted: {class_labels[tf.argmax(score)]}")
# Out:
# ✅ Image found! Proceeding with prediction...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-699d41015035> in <cell line: 0>()
#      18
#      19 # Make predictions
# ---> 20 predictions = loaded_model.predict(img_array)
#      21 class_labels = ["Colon Adenocarcinoma", "Colon Benign Tissue", "Lung Adenocarcinoma", "Lung Benign Tissue", "Lung Squamous Cell Carcinoma"]  # Update as per your classes
#      22 score = tf.nn.softmax(predictions[0])
#
# NameError: name 'loaded_model' is not defined

# %%
from keras.models import load_model
from keras.preprocessing import image
import numpy as np

# Load the model
model = load_model('/content/Model.h5')

# Define class labels in same order as training
class_names = ['colon_aca', 'colon_n', 'lung_aca', 'lung_n', 'lung_scc']

def predict_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # Normalize

    predictions = model.predict(img_array)
    predicted_class = class_names[np.argmax(predictions)]
    confidence = np.max(predictions)

    print(f"Predicted Class: {predicted_class} ({confidence * 100:.2f}% confidence)")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from PIL import Image
import tensorflow as tf

# Correct image path (pick an available image)
image_path = "/content/cancer_data/lung_colon_image_set/lung_image_sets/lung_aca/lungaca794.jpeg"

# Check if the image exists
if os.path.exists(image_path):
    print("✅ Image found! Proceeding with prediction...")
else:
    raise FileNotFoundError("❌ Image not found! Double-check the filename or path.")

# Load and preprocess the image
img = Image.open(image_path)
img = img.resize((224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# Make predictions
predictions = loaded_model.predict(img_array)
class_labels = ["Colon Adenocarcinoma", "Colon Benign Tissue", "Lung Adenocarcinoma", "Lung Benign Tissue", "Lung Squamous Cell Carcinoma"]  # Update as per your classes
score = tf.nn.softmax(predictions[0])

# Print predicted class
print(f"Predicted: {class_labels[tf.argmax(score)]}")
# Out:
# ✅ Image found! Proceeding with prediction...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-699d41015035> in <cell line: 0>()
#      18
#      19 # Make predictions
# ---> 20 predictions = loaded_model.predict(img_array)
#      21 class_labels = ["Colon Adenocarcinoma", "Colon Benign Tissue", "Lung Adenocarcinoma", "Lung Benign Tissue", "Lung Squamous Cell Carcinoma"]  # Update as per your classes
#      22 score = tf.nn.softmax(predictions[0])
#
# NameError: name 'loaded_model' is not defined

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

def predict_image(img_path):
    img = image.load_img(img_path, target_size=img_size)
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    prediction = model.predict(img_array)
    predicted_class = class_names[np.argmax(prediction)]

    # Show image
    plt.imshow(img)
    plt.axis('off')
    plt.title(f'Prediction: {predicted_class}')
    plt.show()

    print(f"Predicted class: {predicted_class}")

# %%
from PIL import Image
import tensorflow as tf

# Correct image path (pick an available image)
image_path = "/content/cancer_data/lung_colon_image_set/lung_image_sets/lung_aca/lungaca794.jpeg"

# Check if the image exists
if os.path.exists(image_path):
    print("✅ Image found! Proceeding with prediction...")
else:
    raise FileNotFoundError("❌ Image not found! Double-check the filename or path.")

# Load and preprocess the image
img = Image.open(image_path)
img = img.resize((224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# Make predictions
predictions = loaded_model.predict(img_array)
class_labels = ["Colon Adenocarcinoma", "Colon Benign Tissue", "Lung Adenocarcinoma", "Lung Benign Tissue", "Lung Squamous Cell Carcinoma"]  # Update as per your classes
score = tf.nn.softmax(predictions[0])

# Print predicted class
print(f"Predicted: {class_labels[tf.argmax(score)]}")
# Out:
# ✅ Image found! Proceeding with prediction...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-699d41015035> in <cell line: 0>()
#      18
#      19 # Make predictions
# ---> 20 predictions = loaded_model.predict(img_array)
#      21 class_labels = ["Colon Adenocarcinoma", "Colon Benign Tissue", "Lung Adenocarcinoma", "Lung Benign Tissue", "Lung Squamous Cell Carcinoma"]  # Update as per your classes
#      22 score = tf.nn.softmax(predictions[0])
#
# NameError: name 'loaded_model' is not defined

# %%
from tensorflow.keras.models import load_model

# Replace with your actual file name if different
model = load_model('Model.h5')

print("Model loaded successfully!")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully!

# %%
from PIL import Image
import tensorflow as tf

# Correct image path (pick an available image)
image_path = "/content/cancer_data/lung_colon_image_set/lung_image_sets/lung_aca/lungaca794.jpeg"

# Check if the image exists
if os.path.exists(image_path):
    print("✅ Image found! Proceeding with prediction...")
else:
    raise FileNotFoundError("❌ Image not found! Double-check the filename or path.")

# Load and preprocess the image
img = Image.open(image_path)
img = img.resize((224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# Make predictions
predictions = loaded_model.predict(img_array)
class_labels = ["Colon Adenocarcinoma", "Colon Benign Tissue", "Lung Adenocarcinoma", "Lung Benign Tissue", "Lung Squamous Cell Carcinoma"]  # Update as per your classes
score = tf.nn.softmax(predictions[0])

# Print predicted class
print(f"Predicted: {class_labels[tf.argmax(score)]}")
# Out:
# ✅ Image found! Proceeding with prediction...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-699d41015035> in <cell line: 0>()
#      18
#      19 # Make predictions
# ---> 20 predictions = loaded_model.predict(img_array)
#      21 class_labels = ["Colon Adenocarcinoma", "Colon Benign Tissue", "Lung Adenocarcinoma", "Lung Benign Tissue", "Lung Squamous Cell Carcinoma"]  # Update as per your classes
#      22 score = tf.nn.softmax(predictions[0])
#
# NameError: name 'loaded_model' is not defined

# %%
import os
for item in os.listdir('/content'):
    print(item)
# Out:
# .config
# Model.h5
# lung-and-colon-cancer-histopathological-images.zip
# cancer_data
# sample_data

# %%
import os

path = '/content/cancer_data'
for folder in os.listdir(path):
    print(folder)
# Out:
# lung_colon_image_set

# %%
image_base = '/content/cancer_data/lung_colon_image_set'
for subfolder in os.listdir(image_base):
    print(subfolder)
# Out:
# colon_image_sets
# lung_image_sets

# %%
colon_path = '/content/cancer_data/lung_colon_image_set/colon_image_sets'
print("Colon Classes:")
for folder in os.listdir(colon_path):
    print(folder)
# Out:
# Colon Classes:
# colon_aca
# colon_n

# %%
test_path = '/content/cancer_data/lung_colon_image_set/colon_image_sets/colon_aca'
for img in os.listdir(test_path)[:5]:
    print(img)
# Out:
# colonca4652.jpeg
# colonca193.jpeg
# colonca2397.jpeg
# colonca4588.jpeg
# colonca1318.jpeg

# %%
from keras.models import load_model
from keras.preprocessing import image
import numpy as np

# Load the model
model = load_model('/content/Model.h5')

# Define class labels in same order as training
class_names = ['colon_aca', 'colon_n', 'lung_aca', 'lung_n', 'lung_scc']

def predict_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # Normalize

    predictions = model.predict(img_array)
    predicted_class = class_names[np.argmax(predictions)]
    confidence = np.max(predictions)

    print(f"Predicted Class: {predicted_class} ({confidence * 100:.2f}% confidence)")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from PIL import Image
import tensorflow as tf
import os

# Load model
loaded_model = tf.keras.models.load_model('/content/Model.h5', compile=False)

# Image path (make sure this exists)
image_path = "/content/cancer_data/lung_colon_image_set/lung_image_sets/lung_aca/lungaca794.jpeg"

if os.path.exists(image_path):
    print("✅ Image found! Proceeding with prediction...")
else:
    raise FileNotFoundError("❌ Image not found! Check the path again.")

# Load and preprocess the image
img = Image.open(image_path).convert('RGB')
img = img.resize((224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# Predict
predictions = loaded_model.predict(img_array)
score = tf.nn.softmax(predictions[0])

# Use correct labels (assuming 3 lung classes)
class_labels = ["Lung Adenocarcinoma", "Lung Normal", "Lung Squamous Cell Carcinoma"]

# Print predicted class
print(f"Predicted: {class_labels[tf.argmax(score)]} ({100 * tf.reduce_max(score):.2f}% confidence)")
# Out:
# ✅ Image found! Proceeding with prediction...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Predicted: Lung Squamous Cell Carcinoma (36.72% confidence)

# %%
from PIL import Image
import tensorflow as tf

# Correct image path (pick an available image)
image_path = "/content/cancer_data/lung_colon_image_set/lung_image_sets/lung_aca/lungaca794.jpeg"

# Check if the image exists
if os.path.exists(image_path):
    print("✅ Image found! Proceeding with prediction...")
else:
    raise FileNotFoundError("❌ Image not found! Double-check the filename or path.")

# Load and preprocess the image
img = Image.open(image_path)
img = img.resize((224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# Make predictions
predictions = loaded_model.predict(img_array)
class_labels = ["Colon Adenocarcinoma", "Colon Benign Tissue", "Lung Adenocarcinoma", "Lung Benign Tissue", "Lung Squamous Cell Carcinoma"]  # Update as per your classes
score = tf.nn.softmax(predictions[0])

# Print predicted class
print(f"Predicted: {class_labels[tf.argmax(score)]}")
# Out:
# ✅ Image found! Proceeding with prediction...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 812ms/step
# Predicted: Lung Adenocarcinoma

# %%
import os
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
import random

# Correct path for Lung Adenocarcinoma image
image_path = "/content/cancer_data/lung_colon_image_set/lung_image_sets/lung_aca/lungaca794.jpeg"  # Change if needed

# Check image existence
if os.path.exists(image_path):
    print("✅ Image found! Proceeding with prediction...")
else:
    raise FileNotFoundError("❌ Image not found! Double-check the filename or path.")

# Load and preprocess image
img = Image.open(image_path).convert("RGB")
img = img.resize((224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# Predict using preloaded model
predictions = loaded_model.predict(img_array)

# Class labels
class_labels = [
    "Colon Adenocarcinoma",
    "Colon Benign Tissue",
    "Lung Adenocarcinoma",
    "Lung Benign Tissue",
    "Lung Squamous Cell Carcinoma"
]

# Get predicted class
predicted_class = class_labels[tf.argmax(predictions[0])]
print(f"Predicted: {predicted_class}")

# Show image
plt.imshow(img)
plt.axis('off')
plt.title(f"Prediction: {predicted_class}")
plt.show()

# Personalized treatment & Indian doctor info for Lung Adenocarcinoma
if predicted_class == "Lung Adenocarcinoma":
    print("\n⚠️ Diagnosis: Lung Adenocarcinoma (a type of lung cancer)\n")

    print("📌 Recommended Treatment Options:")
    print("- Surgery: If detected early, removal of the affected lobe or segment.")
    print("- Targeted Therapy: For specific genetic mutations (EGFR, ALK, ROS1).")
    print("- Immunotherapy: If the tumor has high PD-L1 expression.")
    print("- Chemotherapy/Radiotherapy: For more advanced stages.")
    print("- Palliative Care: For symptom management if not curable.")

    print("\n✅ Additional Recommendations:")
    print("- Genetic testing for targeted therapy eligibility.")
    print("- Avoid smoking and exposure to pollutants.")
    print("- Nutritional support and counseling.")
    print("- Regular follow-ups and scans for progress monitoring.")

    # Generate a random Indian doctor name and number
    indian_doctors = ["Dr. Ashwin Mehta", "Dr. Priya Reddy", "Dr. Vikram Desai", "Dr. Neha Sharma", "Dr. Arjun Banerjee"]
    doctor_phone = f"+91-{random.randint(7000000000, 9999999999)}"
    selected_doctor = random.choice(indian_doctors)

    print(f"\n👨‍⚕️ Suggested Specialist: {selected_doctor}")
    print(f"📞 Contact: {doctor_phone}")
    print("🏥 Specialization: Pulmonology / Oncology (Lung Cancer Specialist)")
# Out:
# ✅ Image found! Proceeding with prediction...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step
# Predicted: Lung Adenocarcinoma
# ⚠️ Diagnosis: Lung Adenocarcinoma (a type of lung cancer)
#
# 📌 Recommended Treatment Options:
# - Surgery: If detected early, removal of the affected lobe or segment.
# - Targeted Therapy: For specific genetic mutations (EGFR, ALK, ROS1).
# - Immunotherapy: If the tumor has high PD-L1 expression.
# - Chemotherapy/Radiotherapy: For more advanced stages.
# - Palliative Care: For symptom management if not curable.
#
# ✅ Additional Recommendations:
# - Genetic testing for targeted therapy eligibility.
# - Avoid smoking and exposure to pollutants.
# - Nutritional support and counseling.
# - Regular follow-ups and scans for progress monitoring.
#
# 👨‍⚕️ Suggested Specialist: Dr. Neha Sharma
# 📞 Contact: +91-8492064616
# 🏥 Specialization: Pulmonology / Oncology (Lung Cancer Specialist)

# %%
import os
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
import random

# Correct image path for Lung Benign Tissue
image_path = "/content/cancer_data/lung_colon_image_set/lung_image_sets/lung_n/lungn2001.jpeg"  # Update as needed

# Check if the image exists
if os.path.exists(image_path):
    print("✅ Image found! Proceeding with prediction...")
else:
    raise FileNotFoundError("❌ Image not found! Double-check the filename or path.")

# Load and preprocess the image
img = Image.open(image_path).convert("RGB")
img = img.resize((224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# Predict using already-loaded model
predictions = loaded_model.predict(img_array)

# Class labels (ensure correct order)
class_labels = [
    "Colon Adenocarcinoma",
    "Colon Benign Tissue",
    "Lung Adenocarcinoma",
    "Lung Benign Tissue",
    "Lung Squamous Cell Carcinoma"
]

predicted_class = class_labels[tf.argmax(predictions[0])]

# Print prediction
print(f"Predicted: {predicted_class}")

# Display image
plt.imshow(img)
plt.axis('off')
plt.title(f"Prediction: {predicted_class}")
plt.show()

# Personalized advice if class is Lung Benign Tissue
if predicted_class == "Lung Benign Tissue":
    print("\n✅ Your lung tissue appears benign.")
    print("This means there is no sign of cancer in the scanned tissue.")
    print("However, regular follow-ups and healthy habits are important.\n")

    print("Recommended actions:")
    print("- Maintain a healthy lifestyle with a balanced diet and exercise.")
    print("- Avoid smoking or exposure to pollutants.")
    print("- Get regular check-ups if you have a history of lung issues.")
    print("- Monitor for any new symptoms like persistent cough or breathlessness.")

    # Indian doctor suggestions
    doctor_names = ["Dr. Meera Joshi", "Dr. Rohan Verma", "Dr. Kavita Iyer", "Dr. Anil Nair", "Dr. Sneha Kapoor"]
    doctor_phone_numbers = [f"+91-{random.randint(9000000000, 9999999999)}" for _ in range(len(doctor_names))]

    index = random.randint(0, len(doctor_names)-1)
    print(f"\n📞 Recommended Consultation:\nDoctor: {doctor_names[index]}\nPhone: {doctor_phone_numbers[index]}")
# Out:
# ✅ Image found! Proceeding with prediction...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# Predicted: Lung Benign Tissue
# ✅ Your lung tissue appears benign.
# This means there is no sign of cancer in the scanned tissue.
# However, regular follow-ups and healthy habits are important.
#
# Recommended actions:
# - Maintain a healthy lifestyle with a balanced diet and exercise.
# - Avoid smoking or exposure to pollutants.
# - Get regular check-ups if you have a history of lung issues.
# - Monitor for any new symptoms like persistent cough or breathlessness.
#
# 📞 Recommended Consultation:
# Doctor: Dr. Sneha Kapoor
# Phone: +91-9013185515

# %%
import os
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
import random

# Correct image path for Lung Squamous Cell Carcinoma (replace with an actual path)
image_path = "/content/cancer_data/lung_colon_image_set/lung_image_sets/lung_scc/lungscc2345.jpeg"  # Change this to your Lung Squamous Cell Carcinoma image path

# Check if the image exists
if os.path.exists(image_path):
    print("✅ Image found! Proceeding with prediction...")
else:
    raise FileNotFoundError("❌ Image not found! Double-check the filename or path.")

# Load and preprocess the image
img = Image.open(image_path).convert("RGB")
img = img.resize((224, 224))  # Resize to expected size (224x224 for most models)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Add batch dimension

# Assuming your model is already loaded (do not load again)
# 'loaded_model' is already available in your environment

# Make prediction
predictions = loaded_model.predict(img_array)

# Class labels as per your model (make sure these match your model's output classes)
class_labels = [
    "Colon Adenocarcinoma",
    "Colon Benign Tissue",
    "Lung Adenocarcinoma",
    "Lung Benign Tissue",
    "Lung Squamous Cell Carcinoma"
]

# Output prediction
predicted_class = class_labels[tf.argmax(predictions[0])]

# Print the predicted class
print(f"Predicted: {predicted_class}")

# Personalized treatment and doctor information for Lung Squamous Cell Carcinoma
if predicted_class == "Lung Squamous Cell Carcinoma":
    print("\n⚠️ Personalized Treatment Recommendation:")
    print("Lung Squamous Cell Carcinoma is a form of non-small cell lung cancer, and treatment depends on the stage of cancer and overall health. Common approaches include:")
    print("1. Surgery: In the early stages, surgery may be used to remove the tumor or affected parts of the lung.")
    print("2. Radiation Therapy: This can be used to target and shrink tumors that can't be removed surgically.")
    print("3. Chemotherapy: Often used when the cancer has spread to other parts of the body or as part of the initial treatment.")
    print("4. Targeted Therapy: For advanced cases, targeted therapy drugs may be used to block the growth of cancer cells.")
    print("5. Immunotherapy: This may be suggested in some cases, especially if cancer has spread to other organs.")
    print("6. Palliative Care: If cancer is in an advanced stage, the focus may shift to managing symptoms and improving quality of life.")

    print("\nIt is critical to work closely with an oncologist to determine the best course of treatment.")

    # Indian doctor names and phone numbers (formatted with an Indian country code)
    doctor_names = ["Dr. Rajesh Kumar", "Dr. Aarti Patel", "Dr. Ravi Sharma", "Dr. Priya Desai", "Dr. Amit Singh"]
    doctor_phone_numbers = [f"+91-{random.randint(9000000000, 9999999999)}",
                            f"+91-{random.randint(9000000000, 9999999999)}",
                            f"+91-{random.randint(9000000000, 9999999999)}",
                            f"+91-{random.randint(9000000000, 9999999999)}",
                            f"+91-{random.randint(9000000000, 9999999999)}"]

    # Randomly pick a doctor and contact number
    doctor_index = random.randint(0, len(doctor_names)-1)
    doctor_name = doctor_names[doctor_index]
    doctor_phone = doctor_phone_numbers[doctor_index]

    print(f"\n📞 Contact Information:\nDr. {doctor_name} - Phone: {doctor_phone}")

# Display the image with predicted class in the title
plt.imshow(img)
plt.axis('off')  # Hide axes for better visualization
plt.title(f"Prediction: {predicted_class}")
plt.show()
# Out:
# ✅ Image found! Proceeding with prediction...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step
# Predicted: Lung Squamous Cell Carcinoma
#
# ⚠️ Personalized Treatment Recommendation:
# Lung Squamous Cell Carcinoma is a form of non-small cell lung cancer, and treatment depends on the stage of cancer and overall health. Common approaches include:
# 1. Surgery: In the early stages, surgery may be used to remove the tumor or affected parts of the lung.
# 2. Radiation Therapy: This can be used to target and shrink tumors that can't be removed surgically.
# 3. Chemotherapy: Often used when the cancer has spread to other parts of the body or as part of the initial treatment.
# 4. Targeted Therapy: For advanced cases, targeted therapy drugs may be used to block the growth of cancer cells.
# 5. Immunotherapy: This may be suggested in some cases, especially if cancer has spread to other organs.
# ...

# %%
import os
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
import random

# Correct image path (you can replace with any colon adenocarcinoma image)
image_path = "/content/cancer_data/lung_colon_image_set/colon_image_sets/colon_aca/colonca2397.jpeg"

# Check image path
if os.path.exists(image_path):
    print("✅ Image found! Proceeding with prediction...")
else:
    raise FileNotFoundError("❌ Image not found! Double-check the filename or path.")

# Load and preprocess the image
img = Image.open(image_path).convert("RGB")
img = img.resize((224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# Prediction using already loaded model
predictions = loaded_model.predict(img_array)

# Class labels
class_labels = [
    "Colon Adenocarcinoma",
    "Colon Benign Tissue",
    "Lung Adenocarcinoma",
    "Lung Benign Tissue",
    "Lung Squamous Cell Carcinoma"
]

predicted_class = class_labels[tf.argmax(predictions[0])]
print(f"Predicted: {predicted_class}")

# Show image
plt.imshow(img)
plt.axis('off')
plt.title(f"Prediction: {predicted_class}")
plt.show()

# If Colon Adenocarcinoma
if predicted_class == "Colon Adenocarcinoma":
    print("\n⚠️ Diagnosis: Colon Adenocarcinoma (Colon Cancer)\n")

    print("📌 Recommended Treatments:")
    print("1. Surgery (Colectomy): Removing the part of colon with cancer and reconnecting the healthy parts.")
    print("2. Chemotherapy: Drugs to destroy cancer cells (e.g., FOLFOX regimen).")
    print("3. Targeted Therapy: For tumors with mutations (e.g., anti-EGFR therapies like Cetuximab).")
    print("4. Immunotherapy: Suitable for MSI-High or dMMR colon cancers (e.g., Pembrolizumab).")
    print("5. Radiation Therapy: Rare but used in rectal cancer or advanced cases.")
    print("6. Lifestyle Changes: Nutrition support, emotional care, and follow-ups.")

    print("\n🏥 Top Hospitals in India for Colon Cancer:")
    hospitals = [
        "1. Tata Memorial Hospital, Mumbai",
        "2. AIIMS, New Delhi",
        "3. Apollo Hospitals, Chennai",
        "4. Fortis Memorial Research Institute, Gurgaon",
        "5. Manipal Hospitals, Bangalore",
        "6. Christian Medical College (CMC), Vellore",
        "7. Rajiv Gandhi Cancer Institute, Delhi",
        "8. Kokilaben Dhirubhai Ambani Hospital, Mumbai"
    ]
    for h in hospitals:
        print(h)

    print("\n✅ Additional Advice:")
    print("- Schedule routine colonoscopies")
    print("- Genetic counseling for family history")
    print("- High-fiber, low-fat diet")
    print("- Limit red meat, alcohol, and quit smoking")
    print("- Stay physically active and emotionally supported")

    # Doctor info
    indian_doctors = [
        ("Dr. Kavita Nair", "Gastrointestinal Oncologist"),
        ("Dr. Rajesh Pillai", "Colorectal Surgeon"),
        ("Dr. Meenakshi Agarwal", "Surgical Oncologist"),
        ("Dr. Suresh Patil", "GI & Laparoscopic Surgeon"),
        ("Dr. Anjali Menon", "Medical Oncologist")
    ]
    selected_doctor = random.choice(indian_doctors)
    phone_number = f"+91-{random.randint(7000000000, 9999999999)}"

    print(f"\n👩‍⚕️ Doctor: {selected_doctor[0]}")
    print(f"🏥 Specialty: {selected_doctor[1]}")
    print(f"📞 Contact: {phone_number}")
# Out:
# ✅ Image found! Proceeding with prediction...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# Predicted: Colon Adenocarcinoma
# ⚠️ Diagnosis: Colon Adenocarcinoma (Colon Cancer)
#
# 📌 Recommended Treatments:
# 1. Surgery (Colectomy): Removing the part of colon with cancer and reconnecting the healthy parts.
# 2. Chemotherapy: Drugs to destroy cancer cells (e.g., FOLFOX regimen).
# 3. Targeted Therapy: For tumors with mutations (e.g., anti-EGFR therapies like Cetuximab).
# 4. Immunotherapy: Suitable for MSI-High or dMMR colon cancers (e.g., Pembrolizumab).
# 5. Radiation Therapy: Rare but used in rectal cancer or advanced cases.
# 6. Lifestyle Changes: Nutrition support, emotional care, and follow-ups.
#
# 🏥 Top Hospitals in India for Colon Cancer:
# 1. Tata Memorial Hospital, Mumbai
# 2. AIIMS, New Delhi
# 3. Apollo Hospitals, Chennai
# 4. Fortis Memorial Research Institute, Gurgaon
# 5. Manipal Hospitals, Bangalore
# 6. Christian Medical College (CMC), Vellore
# ...

# %%
import os
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
import random

# Correct image path (replace with other colon_n images if needed)
image_path = "/content/cancer_data/lung_colon_image_set/colon_image_sets/colon_n/colonn3582.jpeg"

# Check image path
if os.path.exists(image_path):
    print("✅ Image found! Proceeding with prediction...")
else:
    raise FileNotFoundError("❌ Image not found! Check the file path.")

# Load and preprocess the image
img = Image.open(image_path).convert("RGB")
img = img.resize((224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# Predict using loaded model
predictions = loaded_model.predict(img_array)

# Class labels
class_labels = [
    "Colon Adenocarcinoma",
    "Colon Benign Tissue",
    "Lung Adenocarcinoma",
    "Lung Benign Tissue",
    "Lung Squamous Cell Carcinoma"
]

predicted_class = class_labels[tf.argmax(predictions[0])]
print(f"Predicted: {predicted_class}")

# Show image
plt.imshow(img)
plt.axis('off')
plt.title(f"Prediction: {predicted_class}")
plt.show()

# If Colon Benign Tissue
if predicted_class == "Colon Benign Tissue":
    print("\n🟢 Diagnosis: Colon Benign Tissue")
    print("This indicates no presence of cancerous cells in the tissue image.\n")

    print("✅ Recommendations:")
    print("- Continue regular screening every 5–10 years (colonoscopy)")
    print("- Maintain a high-fiber, plant-based diet")
    print("- Avoid processed meats and excessive alcohol")
    print("- Keep physically active")
    print("- Monitor for symptoms: changes in bowel habits, unexplained weight loss, fatigue, etc.")

    print("\n🏥 Top Hospitals in India (for regular screening and follow-up):")
    hospitals = [
        "1. AIIMS, New Delhi",
        "2. Tata Memorial Hospital, Mumbai",
        "3. Apollo Hospitals, Hyderabad",
        "4. Fortis Hospital, Bangalore",
        "5. CMC, Vellore"
    ]
    for h in hospitals:
        print(h)

    # Doctor information
    indian_doctors = [
        ("Dr. Priya Venkatesh", "Gastroenterologist"),
        ("Dr. Aditya Narayan", "GI Specialist"),
        ("Dr. Neelam Suri", "Digestive Health Consultant"),
        ("Dr. Rohit Mehra", "Colorectal Surgeon"),
        ("Dr. Lata Deshmukh", "Preventive Care Specialist")
    ]
    selected_doctor = random.choice(indian_doctors)
    phone_number = f"+91-{random.randint(7000000000, 9999999999)}"

    print(f"\n👨‍⚕️ Doctor: {selected_doctor[0]}")
    print(f"🏥 Specialty: {selected_doctor[1]}")
    print(f"📞 Contact: {phone_number}")
# Out:
# ✅ Image found! Proceeding with prediction...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# Predicted: Colon Benign Tissue
# 🟢 Diagnosis: Colon Benign Tissue
# This indicates no presence of cancerous cells in the tissue image.
#
# ✅ Recommendations:
# - Continue regular screening every 5–10 years (colonoscopy)
# - Maintain a high-fiber, plant-based diet
# - Avoid processed meats and excessive alcohol
# - Keep physically active
# - Monitor for symptoms: changes in bowel habits, unexplained weight loss, fatigue, etc.
#
# 🏥 Top Hospitals in India (for regular screening and follow-up):
# 1. AIIMS, New Delhi
# 2. Tata Memorial Hospital, Mumbai
# 3. Apollo Hospitals, Hyderabad
# 4. Fortis Hospital, Bangalore
# 5. CMC, Vellore
#
# 👨‍⚕️ Doctor: Dr. Neelam Suri
# 🏥 Specialty: Digestive Health Consultant
# 📞 Contact: +91-7395237874

# %%
# Required libraries
import os
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
import datetime

# Correct path for Colon Adenocarcinoma image
image_path = "/content/cancer_data/lung_colon_image_set/colon_image_sets/colon_aca/colonca2397.jpeg"

# Check image path
if os.path.exists(image_path):
    print("✅ Image found! Proceeding with prediction...")
else:
    raise FileNotFoundError("❌ Image not found! Double-check the path.")

# Load and preprocess the image
img = Image.open(image_path).convert("RGB")
img = img.resize((224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# Predict using already loaded model
predictions = loaded_model.predict(img_array)
class_labels = [
    "Colon Adenocarcinoma",
    "Colon Benign Tissue",
    "Lung Adenocarcinoma",
    "Lung Benign Tissue",
    "Lung Squamous Cell Carcinoma"
]
predicted_class = class_labels[tf.argmax(predictions[0])]

# Display image with prediction
plt.imshow(img)
plt.axis('off')
plt.title(f"Prediction: {predicted_class}")
plt.show()

# Personalized treatment plan for Colon Adenocarcinoma
if predicted_class == "Colon Adenocarcinoma":
    treatment = """
    1. Surgery: Partial or total colectomy depending on the stage.
    2. Chemotherapy: Often includes FOLFOX or CAPOX regimens.
    3. Targeted Therapy: EGFR or VEGF inhibitors based on genetic tests.
    4. Immunotherapy: For MSI-high or dMMR tumors.
    5. Regular follow-up with PET/CT scans and colonoscopies.
    """

    doctor = {
        "name": "Dr. Anil Mehta",
        "specialty": "Gastrointestinal Oncologist",
        "phone": "+91-9876543210"
    }

    hospitals = [
        "Tata Memorial Hospital, Mumbai",
        "AIIMS, New Delhi",
        "Apollo Cancer Centre, Chennai",
        "Max Super Specialty Hospital, Delhi",
        "Fortis Memorial Research Institute, Gurgaon"
    ]

    # Print personalized output
    print("\n=== Personalized Recommendation ===")
    print("Diagnosis:", predicted_class)
    print("\nTreatment Plan:\n", treatment)
    print(f"\nConsult: {doctor['name']} ({doctor['specialty']})")
    print("Phone:", doctor["phone"])
    print("\nTop Hospitals in India:")
    for h in hospitals:
        print("-", h)

    # Report generation
    now = datetime.datetime.now()
    report = f"""
    --- Cancer Diagnosis Report ---
    Date: {now.strftime('%Y-%m-%d %H:%M:%S')}
    Diagnosis: {predicted_class}

    Treatment Plan:
    {treatment.strip()}

    Consulting Doctor:
    Name: {doctor['name']}
    Specialty: {doctor['specialty']}
    Phone: {doctor['phone']}

    Recommended Hospitals:
    {chr(10).join(hospitals)}

    Keep this report for follow-up and second opinions.
    ---------------------------------
    """

    # Save report to a file
    with open("colon_aca_report.txt", "w") as f:
        f.write(report)

    print("\nReport saved as 'colon_aca_report.txt'.")

else:
    print(f"Predicted class is: {predicted_class}. This script is tailored for Colon Adenocarcinoma.")
# Out:
# ✅ Image found! Proceeding with prediction...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# === Personalized Recommendation ===
# Diagnosis: Colon Adenocarcinoma
#
# Treatment Plan:
#
#     1. Surgery: Partial or total colectomy depending on the stage.
#     2. Chemotherapy: Often includes FOLFOX or CAPOX regimens.
#     3. Targeted Therapy: EGFR or VEGF inhibitors based on genetic tests.
#     4. Immunotherapy: For MSI-high or dMMR tumors.
#     5. Regular follow-up with PET/CT scans and colonoscopies.
#
#
# Consult: Dr. Anil Mehta (Gastrointestinal Oncologist)
# Phone: +91-9876543210
#
# Top Hospitals in India:
# - Tata Memorial Hospital, Mumbai
# - AIIMS, New Delhi
# - Apollo Cancer Centre, Chennai
# - Max Super Specialty Hospital, Delhi
# - Fortis Memorial Research Institute, Gurgaon
#
# Report saved as 'colon_aca_report.txt'.
